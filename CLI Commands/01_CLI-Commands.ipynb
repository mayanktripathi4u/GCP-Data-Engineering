# %% [markdown]
# # Gcloud Commands
#
# * Cloud Storage --> `gsutil`
# * Cloud Bigquery --> `bq`
# * Cloud Bigtable --> `cbt`
# * Kuberenetes --> `kubectl`

# %%
# Display Vesrion and Installed components
# !gcloud --version
# Out:
# Google Cloud SDK 483.0.0
# bq 2.1.6
# core 2024.06.28
# gcloud-crc32c 1.0.0
# gsutil 5.30
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey

# %%
# Initialize authorize and configure gcloud

# !gcloud init

# %%
# Display all the properties for the current configuration
# !gcloud config list
# Out:
# [compute]
# region = us-central1
# zone = us-central1-a
# [core]
# account = gcpmayanktripathi@gmail.com
# disable_usage_reporting = False
# project = proud-climber-421817
# [gcloudignore]
# enabled = true
# [metrics]
# environment = cloudcode.vscode
# environment_version = 2.17.0
#
# Your active configuration is: [default]
#
#
# Updates are available for some Google Cloud CLI components.  To install them,
# please run:
#   $ gcloud components update

# %%
# To set a default Google Cloud Project to work on
# !gcloud config set project

# %%
# Fetch value of a gcloud CLI property
# !gcloud config get-value
# Out:
# ERROR: (gcloud.config.get-value) argument SECTION/PROPERTY: Must be specified.
# Usage: gcloud config get-value SECTION/PROPERTY [optional flags]
#   optional flags may be  --help
#
# For detailed information on this command and its flags, run:
#   gcloud config get-value --help

# %%
# Display current gcloud environment details
# !gcloud info
# Out:
# Google Cloud SDK [483.0.0]
#
# Platform: [Mac OS X, arm] uname_result(system='Darwin', node='Ektas-MacBook-Air.local', release='22.3.0', version='Darwin Kernel Version 22.3.0: Mon Jan 30 20:39:35 PST 2023; root:xnu-8792.81.3~2/RELEASE_ARM64_T8103', machine='arm64')
# Locale: ('en_US', 'UTF-8')
# Python Version: [3.12.5 (main, Aug  6 2024, 19:08:49) [Clang 15.0.0 (clang-1500.1.0.2.5)]]
# Python Location: [/Users/tripathimachine/Desktop/Apps/GitHub_Repo/DevOps_End_To_End_Project/.venv/bin/python3]
# OpenSSL: [OpenSSL 3.3.2 3 Sep 2024]
# Requests Version: [2.25.1]
# urllib3 Version: [1.26.9]
# Default CA certs file: [/opt/homebrew/Caskroom/google-cloud-sdk/474.0.0/google-cloud-sdk/lib/third_party/certifi/cacert.pem]
# Site Packages: [Enabled]
#
# Installation Root: [/opt/homebrew/share/google-cloud-sdk]
# Installed Components:
#   gsutil: [5.30]
#   core: [2024.06.28]
#   bq: [2.1.6]
#   gcloud-crc32c: [1.0.0]
# ...

# %%
# Display gcloud reference documents to specific items
# !gcloud help
# Out:
# NAME
#     gcloud - manage Google Cloud resources and developer workflow
#
# SYNOPSIS
#     gcloud GROUP | COMMAND [--account=ACCOUNT]
#         [--billing-project=BILLING_PROJECT] [--configuration=CONFIGURATION]
#         [--flags-file=YAML_FILE] [--flatten=[KEY,...]] [--format=FORMAT]
#         [--help] [--project=PROJECT_ID] [--quiet, -q]
#         [--verbosity=VERBOSITY; default="warning"] [--version, -v] [-h]
#         [--access-token-file=ACCESS_TOKEN_FILE]
#         [--impersonate-service-account=SERVICE_ACCOUNT_EMAILS] [--log-http]
#         [--trace-token=TRACE_TOKEN] [--no-user-output-enabled]
#
# DESCRIPTION
#     The gcloud CLI manages authentication, local configuration, developer
#     workflow, and interactions with the Google Cloud APIs.
#
#     For a quick introduction to the gcloud CLI, a list of commonly used
#     commands, and a look at how these commands are structured, run gcloud
#     cheat-sheet or see the `gcloud` CLI cheat sheet
# ...
